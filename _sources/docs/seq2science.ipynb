# %% [markdown]
# ## Preprocessing with seq2science
#
# Sample sheet used with seq2science

# %%
import os
import sys
import inspect

import pandas as pd

# prepare to fetch our util
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

import analysis.util as util


pd.set_option('display.max_rows', None)

samples_table = pd.read_csv(util.samples_url, sep="\t", index_col=0)
samples_table
# Out:
#                                 assembly  condition  replicate     hpf  \
# sample
# TShield_1                    ASM318616v1     shield        NaN   27.00
# TShield_2                    ASM318616v1     shield        NaN   27.00
# T80e_1                       ASM318616v1  80epiboly        NaN   32.00
# T80e_2                       ASM318616v1  80epiboly        NaN   32.00
# T8som_1                      ASM318616v1       8som        NaN   46.00
# T8som_2                      ASM318616v1       8som        NaN   46.00
# TPhylo_1                     ASM318616v1      phylo        NaN   72.00
# TPhylo_2                     ASM318616v1      phylo        NaN   72.00
# SF80e_1           Astyanax_mexicanus-2.0  80epiboly        NaN    8.00
# SF80e_2           Astyanax_mexicanus-2.0  80epiboly        NaN    8.00
# SF80e_3           Astyanax_mexicanus-2.0  80epiboly        NaN    8.00
# SF5ss_1           Astyanax_mexicanus-2.0   5somites        NaN   12.00
# SF5ss_2           Astyanax_mexicanus-2.0   5somites        NaN   12.00
# SF24hpf_2         Astyanax_mexicanus-2.0      24hpf        NaN   24.00
# SF24hpf_3         Astyanax_mexicanus-2.0      24hpf        NaN   24.00
# SF48hpf_2         Astyanax_mexicanus-2.0      48hpf        NaN   48.00
# SF48hpf_3         Astyanax_mexicanus-2.0      48hpf        NaN   48.00
# Xt_stage9_rep2                   xenTro9        st9        NaN    7.00
# Xt_stage105_rep2                 xenTro9     st10.5        NaN   11.00
# Xt_stage105_rep3                 xenTro9     st10.5        NaN   11.00
# Xt_stage12_rep1                  xenTro9       st12        NaN   13.25
# Xt_stage12_rep2                  xenTro9       st12        NaN   13.25
# Xt_stage16_rep2                  xenTro9       st16        NaN   18.25
# Xt_stage16_rep1                  xenTro9       st16        NaN   18.25
# Xt_stage26_rep1                  xenTro9       st26        NaN   29.50
# Xt_stage26_rep2                  xenTro9       st26        NaN   29.50
# Xt_stage34_rep1                  xenTro9       st34        NaN   44.50
# Xt_stage34_rep2                  xenTro9       st34        NaN   44.50
# GSM2837485                       BraLan2       8hpf        NaN    8.00
# GSM2837486                       BraLan2       8hpf        NaN    8.00
# GSM2837480                       BraLan2      15hpf        NaN   15.00
# GSM2837481                       BraLan2      15hpf        NaN   15.00
# GSM2837482                       BraLan2      36hpf        NaN   36.00
# GSM2837483                       BraLan2      60hpf        NaN   60.00
# GSM2837484                       BraLan2      60hpf        NaN   60.00
# GSM3756599                      danRer11    256cell        NaN    2.50
# GSM3756600                      danRer11    256cell        NaN    2.50
# GSM3756606                      danRer11       high        NaN    3.30
# GSM3756607                      danRer11       high        NaN    3.30
# GSM3756608                      danRer11       high        NaN    3.30
# GSM3756609                      danRer11     oblong        NaN    3.60
# GSM3756610                      danRer11     oblong        NaN    3.60
# GSM3756611                      danRer11     oblong        NaN    3.60
# GSM3756614                      danRer11     sphere        NaN    4.00
# GSM3756615                      danRer11     sphere        NaN    4.00
# GSM2837495                      danRer11       dome        NaN    4.30
# GSM2837497                      danRer11       dome        NaN    4.30
# GSM3756603                      danRer11       dome        NaN    4.30
# GSM3756604                      danRer11       dome        NaN    4.30
# GSM3756605                      danRer11       dome        NaN    4.30
# GSM2837496                      danRer11     shield        NaN    6.00
# GSM2837498                      danRer11     shield        NaN    6.00
# GSM3756612                      danRer11     shield        NaN    6.00
# GSM3756613                      danRer11     shield        NaN    6.00
# GSM2837491                      danRer11  80epiboly        NaN    8.50
# GSM2837492                      danRer11  80epiboly        NaN    8.50
# GSM3756601                      danRer11  80epiboly        NaN    8.50
# GSM3756602                      danRer11  80epiboly        NaN    8.50
# GSM2837493                      danRer11   8somites        NaN   13.00
# GSM2837494                      danRer11   8somites        NaN   13.00
# GSM3494511                      danRer11   8somites        NaN   13.00
# GSM3494510                      danRer11   8somites        NaN   13.00
# GSM3494509                      danRer11      36hpf        NaN   36.00
# GSM3494508                      danRer11      36hpf        NaN   36.00
# GSM2837489                      danRer11      48hpf        NaN   48.00
# GSM2837490                      danRer11      48hpf        NaN   48.00
# DRR138947                         GRCg6a        HH6        NaN   24.00
# DRR138948                         GRCg6a        HH6        NaN   24.00
# DRR138949                         GRCg6a        HH6        NaN   24.00
# DRR138950                         GRCg6a       HH11        NaN   42.50
# DRR138951                         GRCg6a       HH11        NaN   42.50
# DRR138952                         GRCg6a       HH11        NaN   42.50
# DRR138953                         GRCg6a       HH16        NaN   53.50
# DRR138954                         GRCg6a       HH16        NaN   53.50
# DRR138955                         GRCg6a       HH16        NaN   53.50
# DRR138956                         GRCg6a       HH19        NaN   78.00
# DRR138957                         GRCg6a       HH19        NaN   78.00
# DRR138958                         GRCg6a       HH19        NaN   78.00
# DRR138959                         GRCg6a       HH24        NaN  108.00
# DRR138960                         GRCg6a       HH24        NaN  108.00
# DRR138961                         GRCg6a       HH24        NaN  108.00
# DRR138962                         GRCg6a       HH28        NaN  138.00
# DRR138963                         GRCg6a       HH28        NaN  138.00
# DRR138964                         GRCg6a       HH28        NaN  138.00
# DRR138965                         GRCg6a       HH32        NaN  180.00
# DRR138966                         GRCg6a       HH32        NaN  180.00
# DRR138967                         GRCg6a       HH32        NaN  180.00
# DRR138968                         GRCg6a       HH38        NaN  288.00
# DRR138969                         GRCg6a       HH38        NaN  288.00
# DRR138970                         GRCg6a       HH38        NaN  288.00
# DRR138923                         GRCm39      st7.5        NaN  180.00
# DRR138924                         GRCm39      st7.5        NaN  180.00
# DRR138925                         GRCm39      st7.5        NaN  180.00
# DRR138926                         GRCm39      st8.5        NaN  204.00
# DRR138927                         GRCm39      st8.5        NaN  204.00
# DRR138928                         GRCm39      st8.5        NaN  204.00
# DRR138929                         GRCm39      st9.5        NaN  228.00
# DRR138930                         GRCm39      st9.5        NaN  228.00
# DRR138931                         GRCm39      st9.5        NaN  228.00
# DRR138932                         GRCm39     st10.5        NaN  252.00
# DRR138933                         GRCm39     st10.5        NaN  252.00
# DRR138934                         GRCm39     st10.5        NaN  252.00
# DRR138935                         GRCm39     st12.5        NaN  300.00
# DRR138936                         GRCm39     st12.5        NaN  300.00
# DRR138937                         GRCm39     st12.5        NaN  300.00
# DRR138938                         GRCm39     st14.5        NaN  348.00
# DRR138939                         GRCm39     st14.5        NaN  348.00
# DRR138992                         GRCm39     st14.5        NaN  348.00
# DRR138940                         GRCm39     st14.5        NaN  348.00
# DRR138941                         GRCm39     st16.5        NaN  396.00
# DRR138942                         GRCm39     st16.5        NaN  396.00
# DRR138943                         GRCm39     st16.5        NaN  396.00
# DRR138944                         GRCm39     st18.5        NaN  444.00
# DRR138993                         GRCm39     st18.5        NaN  444.00
# DRR138945                         GRCm39     st18.5        NaN  444.00
# DRR138946                         GRCm39     st18.5        NaN  444.00
# DRR138994                         GRCm39     st18.5        NaN  444.00
# GSM2837499                   ASM223467v1       st11        NaN    8.25
# GSM2837500                   ASM223467v1       st11        NaN    8.25
# GSM4039581                   ASM223467v1       st11        NaN    8.25
# GSM4558119                   ASM223467v1       st11        NaN    8.25
# GSM2837501                   ASM223467v1       st13        NaN   13.00
# GSM2837502                   ASM223467v1       st13        NaN   13.00
# DRR138971                    ASM223467v1       st15        NaN   17.50
# DRR138972                    ASM223467v1       st15        NaN   17.50
# DRR138973                    ASM223467v1       st15        NaN   17.50
# GSM4039582                   ASM223467v1       st15        NaN   17.50
# GSM4558120                   ASM223467v1       st15        NaN   17.50
# GSM2837503                   ASM223467v1       st19        NaN   27.50
# GSM2837504                   ASM223467v1       st19        NaN   27.50
# GSM4039583                   ASM223467v1       st19        NaN   27.50
# GSM4558121                   ASM223467v1       st19        NaN   27.50
# DRR138974                    ASM223467v1       st21        NaN   34.00
# DRR138975                    ASM223467v1       st21        NaN   34.00
# DRR138976                    ASM223467v1       st21        NaN   34.00
# DRR138995                    ASM223467v1       st21        NaN   34.00
# DRR138996                    ASM223467v1       st21        NaN   34.00
# DRR138997                    ASM223467v1       st21        NaN   34.00
# DRR138977                    ASM223467v1       st24        NaN   44.00
# DRR138978                    ASM223467v1       st24        NaN   44.00
# DRR138979                    ASM223467v1       st24        NaN   44.00
# GSM2837505                   ASM223467v1       st25        NaN   50.00
# GSM2837506                   ASM223467v1       st25        NaN   50.00
# GSM4558122                   ASM223467v1       st25        NaN   50.00
# GSM4558123                   ASM223467v1       st25        NaN   50.00
# DRR138980                    ASM223467v1       st28        NaN   64.00
# DRR138998                    ASM223467v1       st28        NaN   64.00
# DRR138999                    ASM223467v1       st28        NaN   64.00
# DRR138981                    ASM223467v1       st28        NaN   64.00
# DRR138982                    ASM223467v1       st28        NaN   64.00
# GSM4558124                   ASM223467v1       st29        NaN   74.00
# GSM4558125                   ASM223467v1       st29        NaN   74.00
# GSM2837507                   ASM223467v1       st32        NaN  101.00
# GSM2837508                   ASM223467v1       st32        NaN  101.00
# DRR138983                    ASM223467v1       st32        NaN  101.00
# DRR138984                    ASM223467v1       st32        NaN  101.00
# DRR138985                    ASM223467v1       st32        NaN  101.00
# GSM4558126                   ASM223467v1       st32        NaN  101.00
# GSM4558127                   ASM223467v1       st32        NaN  101.00
# DRR138986                    ASM223467v1       st36        NaN  144.00
# DRR138987                    ASM223467v1       st36        NaN  144.00
# DRR138988                    ASM223467v1       st36        NaN  144.00
# GSM4039587                   ASM223467v1       st36        NaN  144.00
# GSM4558128                   ASM223467v1       st36        NaN  144.00
# GSM4039588                   ASM223467v1       st38        NaN  192.00
# GSM4558129                   ASM223467v1       st38        NaN  192.00
# DRR138989                    ASM223467v1       st40        NaN  216.00
# DRR138990                    ASM223467v1       st40        NaN  216.00
# DRR139001                    ASM223467v1       st40        NaN  216.00
# DRR138991                    ASM223467v1       st40        NaN  216.00
# DRR139002                    ASM223467v1       st40        NaN  216.00
# GSM4039589                   ASM223467v1       st40        NaN  216.00
# GSM4558130                   ASM223467v1       st40        NaN  216.00
#
#                  descriptive_name  control  \
# sample
# TShield_1             shield_rep1      NaN
# TShield_2             shield_rep2      NaN
# T80e_1             80epiboly_rep1      NaN
# T80e_2             80epiboly_rep2      NaN
# T8som_1                 8som_rep1      NaN
# T8som_2                 8som_rep2      NaN
# TPhylo_1               phylo_rep1      NaN
# TPhylo_2               phylo_rep2      NaN
# SF80e_1            80epiboly_rep1      NaN
# SF80e_2            80epiboly_rep2      NaN
# SF80e_3            80epiboly_rep3      NaN
# SF5ss_1             5somites_rep1      NaN
# SF5ss_2             5somites_rep2      NaN
# SF24hpf_2              24hpf_rep1      NaN
# SF24hpf_3              24hpf_rep2      NaN
# SF48hpf_2              48hpf_rep1      NaN
# SF48hpf_3              48hpf_rep2      NaN
# Xt_stage9_rep2           st9_rep2      NaN
# Xt_stage105_rep2      st10.5_rep2      NaN
# Xt_stage105_rep3      st10.5_rep3      NaN
# Xt_stage12_rep1         st12_rep1      NaN
# Xt_stage12_rep2         st12_rep2      NaN
# Xt_stage16_rep2         st16_rep2      NaN
# Xt_stage16_rep1         st16_rep1      NaN
# Xt_stage26_rep1         st26_rep1      NaN
# Xt_stage26_rep2         st26_rep2      NaN
# Xt_stage34_rep1         st34_rep1      NaN
# Xt_stage34_rep2         st34_rep2      NaN
# GSM2837485                8h_rep1      NaN
# GSM2837486                8h_rep2      NaN
# GSM2837480               15h_rep1      NaN
# GSM2837481               15h_rep2      NaN
# GSM2837482               36h_rep1      NaN
# GSM2837483               60h_rep1      NaN
# GSM2837484               60h_rep2      NaN
# GSM3756599           256cell_rep1      NaN
# GSM3756600           256cell_rep2      NaN
# GSM3756606              high_rep1      NaN
# GSM3756607              high_rep2      NaN
# GSM3756608              high_rep3      NaN
# GSM3756609            oblong_rep1      NaN
# GSM3756610            oblong_rep2      NaN
# GSM3756611            oblong_rep3      NaN
# GSM3756614            sphere_rep1      NaN
# GSM3756615            sphere_rep2      NaN
# GSM2837495              dome_rep1      NaN
# GSM2837497              dome_rep2      NaN
# GSM3756603              dome_rep3      NaN
# GSM3756604              dome_rep4      NaN
# GSM3756605              dome_rep5      NaN
# GSM2837496            shield_rep1      NaN
# GSM2837498            shield_rep2      NaN
# GSM3756612            shield_rep3      NaN
# GSM3756613            shield_rep4      NaN
# GSM2837491         80epiboly_rep1      NaN
# GSM2837492         80epiboly_rep2      NaN
# GSM3756601         80epiboly_rep3      NaN
# GSM3756602         80epiboly_rep4      NaN
# GSM2837493          8somites_rep1      NaN
# GSM2837494          8somites_rep2      NaN
# GSM3494511          8somites_rep3      NaN
# GSM3494510           8omites_rep4      NaN
# GSM3494509             36hpf_rep1      NaN
# GSM3494508             36hpf_rep2      NaN
# GSM2837489             48hpf_rep1      NaN
# GSM2837490             48hpf_rep2      NaN
# DRR138947                HH6_rep1      NaN
# DRR138948                HH6_rep2      NaN
# DRR138949                HH6_rep3      NaN
# DRR138950               HH11_rep1      NaN
# DRR138951               HH11_rep2      NaN
# DRR138952               HH11_rep3      NaN
# DRR138953               HH16_rep1      NaN
# DRR138954               HH16_rep2      NaN
# DRR138955               HH16_rep3      NaN
# DRR138956               HH19_rep1      NaN
# DRR138957               HH19_rep2      NaN
# DRR138958               HH19_rep3      NaN
# DRR138959               HH24_rep1      NaN
# DRR138960               HH24_rep2      NaN
# DRR138961               HH24_rep3      NaN
# DRR138962               HH28_rep1      NaN
# DRR138963               HH28_rep2      NaN
# DRR138964               HH28_rep3      NaN
# DRR138965               HH32_rep1      NaN
# DRR138966               HH32_rep2      NaN
# DRR138967               HH32_rep3      NaN
# DRR138968               HH38_rep1      NaN
# DRR138969               HH38_rep2      NaN
# DRR138970               HH38_rep3      NaN
# DRR138923              st7.5_rep1      NaN
# DRR138924              st7.5_rep2      NaN
# DRR138925              st7.5_rep3      NaN
# DRR138926              st8.5_rep1      NaN
# DRR138927              st8.5_rep2      NaN
# DRR138928              st8.5_rep3      NaN
# DRR138929              st9.5_rep1      NaN
# DRR138930              st9.5_rep2      NaN
# DRR138931              st9.5_rep3      NaN
# DRR138932             st10.5_rep1      NaN
# DRR138933             st10.5_rep2      NaN
# DRR138934             st10.5_rep3      NaN
# DRR138935             st12.5_rep1      NaN
# DRR138936             st12.5_rep2      NaN
# DRR138937             st12.5_rep3      NaN
# DRR138938             st14.5_rep1      NaN
# DRR138939             st14.5_rep2      NaN
# DRR138992             st14.5_rep3      NaN
# DRR138940             st14.5_rep4      NaN
# DRR138941             st16.5_rep1      NaN
# DRR138942             st16.5_rep2      NaN
# DRR138943             st16.5_rep3      NaN
# DRR138944             st18.5_rep1      NaN
# DRR138993             st18.5_rep2      NaN
# DRR138945             st18.5_rep3      NaN
# DRR138946             st18.5_rep4      NaN
# DRR138994             st18.5_rep5      NaN
# GSM2837499              st11_rep1      NaN
# GSM2837500              st11_rep2      NaN
# GSM4039581              st11_rep3      NaN
# GSM4558119              st11_rep4      NaN
# GSM2837501              st13_rep1      NaN
# GSM2837502              st13_rep2      NaN
# DRR138971               st15_rep1      NaN
# DRR138972               st15_rep2      NaN
# DRR138973               st15_rep3      NaN
# GSM4039582              st15_rep4      NaN
# GSM4558120              st15_rep5      NaN
# GSM2837503              st19_rep1      NaN
# GSM2837504              st19_rep2      NaN
# GSM4039583              st19_rep3      NaN
# GSM4558121              st19_rep4      NaN
# DRR138974               st21_rep1      NaN
# DRR138975               st21_rep2      NaN
# DRR138976               st21_rep3      NaN
# DRR138995               st21_rep4      NaN
# DRR138996               st21_rep5      NaN
# DRR138997               st21_rep6      NaN
# DRR138977               st24_rep1      NaN
# DRR138978               st24_rep2      NaN
# DRR138979               st24_rep3      NaN
# GSM2837505              st25_rep1      NaN
# GSM2837506              st25_rep2      NaN
# GSM4558122              st25_rep3      NaN
# GSM4558123              st25_rep4      NaN
# DRR138980               st28_rep1      NaN
# DRR138998               st28_rep2      NaN
# DRR138999               st28_rep3      NaN
# DRR138981               st28_rep4      NaN
# DRR138982               st28_rep5      NaN
# GSM4558124              st29_rep1      NaN
# GSM4558125              st29_rep2      NaN
# GSM2837507              st32_rep1      NaN
# GSM2837508              st32_rep2      NaN
# DRR138983               st32_rep3      NaN
# DRR138984               st32_rep4      NaN
# DRR138985               st32_rep5      NaN
# GSM4558126              st32_rep6      NaN
# GSM4558127              st32_rep7      NaN
# DRR138986               st36_rep1      NaN
# DRR138987               st36_rep2      NaN
# DRR138988               st36_rep3      NaN
# GSM4039587              st36_rep4      NaN
# GSM4558128              st36_rep5      NaN
# GSM4039588              st38_rep1      NaN
# GSM4558129              st38_rep2      NaN
# DRR138989               st40_rep1      NaN
# DRR138990               st40_rep2      NaN
# DRR139001               st40_rep3      NaN
# DRR138991               st40_rep4      NaN
# DRR139002               st40_rep5      NaN
# GSM4039589              st40_rep6      NaN
# GSM4558130              st40_rep7      NaN
#
#                                                               study
# sample
# TShield_1                                 unpublished_tena_skarmeta
# TShield_2                                 unpublished_tena_skarmeta
# T80e_1                                    unpublished_tena_skarmeta
# T80e_2                                    unpublished_tena_skarmeta
# T8som_1                                   unpublished_tena_skarmeta
# T8som_2                                   unpublished_tena_skarmeta
# TPhylo_1                                  unpublished_tena_skarmeta
# TPhylo_2                                  unpublished_tena_skarmeta
# SF80e_1                                   unpublished_tena_skarmeta
# SF80e_2                                   unpublished_tena_skarmeta
# SF80e_3                                   unpublished_tena_skarmeta
# SF5ss_1                                   unpublished_tena_skarmeta
# SF5ss_2                                   unpublished_tena_skarmeta
# SF24hpf_2                                 unpublished_tena_skarmeta
# SF24hpf_3                                 unpublished_tena_skarmeta
# SF48hpf_2                                 unpublished_tena_skarmeta
# SF48hpf_3                                 unpublished_tena_skarmeta
# Xt_stage9_rep2                                 unpublished_internal
# Xt_stage105_rep2                               unpublished_internal
# Xt_stage105_rep3                               unpublished_internal
# Xt_stage12_rep1                                unpublished_internal
# Xt_stage12_rep2                                unpublished_internal
# Xt_stage16_rep2                                unpublished_internal
# Xt_stage16_rep1                                unpublished_internal
# Xt_stage26_rep1                                unpublished_internal
# Xt_stage26_rep2                                unpublished_internal
# Xt_stage34_rep1                                unpublished_internal
# Xt_stage34_rep2                                unpublished_internal
# GSM2837485                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837486                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837480                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837481                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837482                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837483                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837484                https://doi.org/10.1038/s41586-018-0734-6
# GSM3756599             https://doi.org/10.1371/journal.pgen.1008546
# GSM3756600             https://doi.org/10.1371/journal.pgen.1008546
# GSM3756606             https://doi.org/10.1371/journal.pgen.1008546
# GSM3756607             https://doi.org/10.1371/journal.pgen.1008546
# GSM3756608             https://doi.org/10.1371/journal.pgen.1008546
# GSM3756609             https://doi.org/10.1371/journal.pgen.1008546
# GSM3756610             https://doi.org/10.1371/journal.pgen.1008546
# GSM3756611             https://doi.org/10.1371/journal.pgen.1008546
# GSM3756614             https://doi.org/10.1371/journal.pgen.1008546
# GSM3756615             https://doi.org/10.1371/journal.pgen.1008546
# GSM2837495                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837497                https://doi.org/10.1038/s41586-018-0734-6
# GSM3756603             https://doi.org/10.1371/journal.pgen.1008546
# GSM3756604             https://doi.org/10.1371/journal.pgen.1008546
# GSM3756605             https://doi.org/10.1371/journal.pgen.1008546
# GSM2837496                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837498                https://doi.org/10.1038/s41586-018-0734-6
# GSM3756612             https://doi.org/10.1371/journal.pgen.1008546
# GSM3756613             https://doi.org/10.1371/journal.pgen.1008546
# GSM2837491                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837492                https://doi.org/10.1038/s41586-018-0734-6
# GSM3756601             https://doi.org/10.1371/journal.pgen.1008546
# GSM3756602             https://doi.org/10.1371/journal.pgen.1008546
# GSM2837493                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837494                https://doi.org/10.1038/s41586-018-0734-6
# GSM3494511               https://doi.org/10.1038/s41467-019-11121-z
# GSM3494510               https://doi.org/10.1038/s41467-019-11121-z
# GSM3494509               https://doi.org/10.1038/s41467-019-11121-z
# GSM3494508               https://doi.org/10.1038/s41467-019-11121-z
# GSM2837489                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837490                https://doi.org/10.1038/s41586-018-0734-6
# DRR138947                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138948                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138949                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138950                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138951                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138952                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138953                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138954                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138955                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138956                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138957                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138958                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138959                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138960                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138961                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138962                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138963                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138964                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138965                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138966                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138967                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138968                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138969                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138970                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138923                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138924                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138925                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138926                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138927                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138928                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138929                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138930                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138931                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138932                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138933                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138934                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138935                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138936                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138937                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138938                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138939                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138992                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138940                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138941                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138942                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138943                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138944                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138993                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138945                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138946                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138994                 https://doi.org/10.1186/s40851-019-0148-9
# GSM2837499                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837500                https://doi.org/10.1038/s41586-018-0734-6
# GSM4039581        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# GSM4558119        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# GSM2837501                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837502                https://doi.org/10.1038/s41586-018-0734-6
# DRR138971                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138972                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138973                 https://doi.org/10.1186/s40851-019-0148-9
# GSM4039582        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# GSM4558120        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# GSM2837503                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837504                https://doi.org/10.1038/s41586-018-0734-6
# GSM4039583        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# GSM4558121        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# DRR138974                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138975                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138976                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138995                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138996                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138997                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138977                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138978                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138979                 https://doi.org/10.1186/s40851-019-0148-9
# GSM2837505                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837506                https://doi.org/10.1038/s41586-018-0734-6
# GSM4558122        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# GSM4558123        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# DRR138980                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138998                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138999                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138981                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138982                 https://doi.org/10.1186/s40851-019-0148-9
# GSM4558124        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# GSM4558125        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# GSM2837507                https://doi.org/10.1038/s41586-018-0734-6
# GSM2837508                https://doi.org/10.1038/s41586-018-0734-6
# DRR138983                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138984                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138985                 https://doi.org/10.1186/s40851-019-0148-9
# GSM4558126        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# GSM4558127        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# DRR138986                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138987                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138988                 https://doi.org/10.1186/s40851-019-0148-9
# GSM4039587        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# GSM4558128        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# GSM4039588        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# GSM4558129        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# DRR138989                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138990                 https://doi.org/10.1186/s40851-019-0148-9
# DRR139001                 https://doi.org/10.1186/s40851-019-0148-9
# DRR138991                 https://doi.org/10.1186/s40851-019-0148-9
# DRR139002                 https://doi.org/10.1186/s40851-019-0148-9
# GSM4039589        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
# GSM4558130        https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi...
