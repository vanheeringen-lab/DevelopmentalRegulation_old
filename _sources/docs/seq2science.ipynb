# %% [markdown]
# ## Preprocessing with seq2science

# %%
import pandas as pd


pd.set_option('display.max_rows', None)

google_spreadsheet = "https://docs.google.com/spreadsheets/d/1X2YiJ-ZlX5usBGFr2L_-Jmt_NkLDJeu8m2jq4OjyEXI/export?gid=664155010&format=tsv"
samples_table = pd.read_csv(google_spreadsheet, sep="\t")
samples_table
# Out:
#                sample                assembly  condition  replicate     hpf  \
# 0           TShield_1             ASM318616v1     shield        NaN   27.00
# 1           TShield_2             ASM318616v1     shield        NaN   27.00
# 2              T80e_1             ASM318616v1  80epiboly        NaN   32.00
# 3              T80e_2             ASM318616v1  80epiboly        NaN   32.00
# 4             T8som_1             ASM318616v1       8som        NaN   46.00
# 5             T8som_2             ASM318616v1       8som        NaN   46.00
# 6            TPhylo_1             ASM318616v1      phylo        NaN   72.00
# 7            TPhylo_2             ASM318616v1      phylo        NaN   72.00
# 8             SF80e_1  Astyanax_mexicanus-2.0  80epiboly        NaN    8.00
# 9             SF80e_2  Astyanax_mexicanus-2.0  80epiboly        NaN    8.00
# 10            SF80e_3  Astyanax_mexicanus-2.0  80epiboly        NaN    8.00
# ...
